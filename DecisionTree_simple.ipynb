# %% [markdown]
# <a href="https://colab.research.google.com/github/angeruzzi/MachineLearningRef/blob/main/DecisionTree_simple.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import KFold, cross_validate
from sklearn.metrics import log_loss, make_scorer

df = pd.read_csv("classificacao_Q1.csv")

X = df.drop(columns=["target"])
y = df["target"]

model = DecisionTreeClassifier(
    criterion="entropy",
    random_state=42
)

cv = KFold(
    n_splits=10,
    shuffle=False
)

scores = cross_validate(
    model,
    X,
    y,
    cv=cv,
    scoring="neg_log_loss",
    return_train_score=True
)

train_logloss = -scores["train_score"].mean()
val_logloss = -scores["test_score"].mean()

print("Train:", train_logloss)
print("Validation:", val_logloss)
